# %% [markdown]
# # initialize data from csv file

# %%
data <- read.csv("regrex1.csv")

x <- data$x
y <- data$y

# %% [markdown]
# # use built-in plot function to draw points and regression line afterwards

# %%
plot(x, y, main = "Scatter in R")
abline(lm(y ~ x))
# Out:
# Plot with title “Scatter in R”
